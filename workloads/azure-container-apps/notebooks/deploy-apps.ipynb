# %% [markdown]
# # Create container app for MCP Server

# %%
import os

with open('.env-deploy') as f:
    for line in f:
        if '=' in line and not line.startswith('#'):
            key, value = line.strip().split('=', 1)
            os.environ[key] = value.strip('"')

# !az containerapp create \
  --name weathermcp \
  --resource-group $RESOURCE_GROUP_NAME \
  --environment $CAE_NAME \
  --image $REGISTRY_NAME \
  --env-vars WEATHER_API_KEY=$WEATHER_API_KEY \
  --target-port 8080 \
  --ingress external \
  --min-replicas 1 \
  --output json

# %%
import os

with open('.env-deploy') as f:
    for line in f:
        if '=' in line and not line.startswith('#'):
            key, value = line.strip().split('=', 1)
            os.environ[key] = value.strip('"')

# !az containerapp show \
  --name weathermcp \
  --resource-group {os.environ['RESOURCE_GROUP_NAME']} \
  --output json

# %%
# !curl -i -X POST https://weathermcp.aca.jogcloud.com/mcp \
  -H "Content-Type: application/json" \
  -H "Accept: application/json, text/event-stream" \
  -d '{"jsonrpc":"2.0","id":1,"method":"initialize","params":{"protocolVersion":"2024-11-05","capabilities":{},"clientInfo":{"name":"curl","version":"1.0"}}}'

# %%
# !curl -X POST https://weathermcp.aca.jogcloud.com/mcp \
  -H "Content-Type: application/json" \
  -H "Accept: application/json, text/event-stream" \
  -H "Mcp-Session-Id: 577dfe638a1e470faf5bad297b2327b2" \
  -d '{"jsonrpc":"2.0","method":"notifications/initialized","params":{}}'

# %%
# !curl -X POST https://weathermcp.aca.jogcloud.com/mcp \
  -H "Content-Type: application/json" \
  -H "Accept: application/json, text/event-stream" \
  -H "Mcp-Session-Id: 577dfe638a1e470faf5bad297b2327b2" \
  -d '{"jsonrpc":"2.0","id":3,"method":"tools/call","params":{"name":"get_weather","arguments":{"city":"Seattle"}}}'
